# %%
# Define paths
data_directory = "/Users/taha/Desktop/rag/rag_data/website/data"
output_directory = "/Users/taha/Desktop/rag/data"

# List of valid categoriy or folder names
folder_names = [
    "Geräte & Zubehör",
    "Hilfe bei Störungen",
    "Internet & Telefonie",
    "MagentaEINS",
    "Mobilfunk",
    "TV",
    "Vertrag & Rechnung",
    "Apps & Dienste"
]

# Define the mapping of category descriptions
category_map = {
    "vertrag_rechnung_ihre_daten_kundencenter_login-daten_rechnung_lieferstatus": "Vertrag & Rechnung",
    "hilfe_stoerungen_stoerungen_selbst_beheben_melden_status_verfolgen": "Hilfe bei Störungen",
    "mobilfunk_tarife_optionen_mobiles-internet_mailbox_esim_sim-karten": "Mobilfunk",
    "internet_telefonie:_ausbau,_sicherheit,_einstellungen,_bauherren,_glasfaser_und_wlan": "Internet & Telefonie",
    "tv_magentatv_streaming-dienste_magentatv_jugendschutz_pins": "TV",
    "magentains_kombi-pakete_mit_magentains_vorteil_und_treuebonus": "MagentaEINS",
    "apps_dienste_e-mail_magenta_apps_voicemail_app_mobilityconnect": "Apps & Dienste",
    "geraete_zubehoer_anleitungen_fuer_smartphones_tablets_telefone_router_receiver": "Geräte & Zubehör"
}

# %%
import os
from pathlib import Path
import requests
from bs4 import BeautifulSoup
import re
import logging
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import time

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Function to create a session with retry logic
def create_session():
    session = requests.Session()
    retries = Retry(total=3, backoff_factor=0.1, status_forcelist=[502, 503, 504])
    adapter = HTTPAdapter(max_retries=retries)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
    return session

# 1. Fetch URLs from Sitemap
sitemap_url = 'https://www.telekom.de/ueber-das-unternehmen/robots/sitemap'
logger.info(f"Requesting sitemap URL: {sitemap_url}")
session = create_session()

try:
    response = session.get(sitemap_url)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    logger.error(f"Error fetching sitemap: {e}")
    exit(1)

# Parse XML sitemap
soup = BeautifulSoup(response.content, 'xml')
logger.info("Processing sitemap XML...")

# Extract URLs
urls = [url.text for url in soup.find_all('loc') if url is not None]
logger.info(f"{len(urls)} URLs found.")

# Function to extract question-answer pairs from the page
def extract_question_answer(soup):
    question_answer_pairs = []

    def get_text_from_element(element):
        text = ''
        for p in element.find_all('p'):
            text += p.get_text(strip=True) + '\n'
        for ul in element.find_all('ul'):
            for li in ul.find_all('li'):
                text += f"• {li.get_text(strip=True)}\n"
        return text.strip()

    def extract_accordion_items(accordion_list):
        for item in accordion_list.find_all('li', class_='accordion-item'):
            question = item.find('p', class_='accordion-item__title')
            answer = item.find('div', class_='accordion-item__content')
            if question and answer:
                question_text = question.get_text(strip=True)
                answer_text = get_text_from_element(answer)
                question_answer_pairs.append({'question': question_text, 'answer': answer_text})

    excluded_classes = [
        "chf-navigation-bar",
        "direct-access-container",
        "direct-access-content",
        "collection-wrapper collection collection-standard",
        "collection-wrapper collection collection-standard l-outer l-outer--solutionPage"
    ]
    
    def remove_excluded_elements(soup):
        for class_name in excluded_classes:
            for element in soup.find_all(class_=class_name):
                if element:
                    element.decompose()

    def remove_nested_excluded_elements(soup):
        for element in soup.find_all(True):
            if isinstance(element, BeautifulSoup):
                classes = element.get('class', [])
                if classes and any(cls in ' '.join(classes) for cls in excluded_classes):
                    element.decompose()
    
    remove_excluded_elements(soup)
    remove_nested_excluded_elements(soup)

    questions = soup.find_all(['h1', 'h2', 'h3'])
    for question in questions:
        question_text = question.get_text(strip=True)
        if question_text.endswith('?'):
            answer_text = ''
            next_div = question.find_next('div', class_='outerRichtextDiv')
            if next_div:
                answer_text = get_text_from_element(next_div)
            if not answer_text:
                next_div = question.find_next('div')
                if next_div and not any(cls in ' '.join(next_div.get('class', [])) for cls in excluded_classes):
                    answer_text = get_text_from_element(next_div)
            if answer_text:
                question_answer_pairs.append({'question': question_text, 'answer': answer_text})

    accordion_list = soup.find('ul', class_='accordion-list')
    if accordion_list:
        extract_accordion_items(accordion_list)

    return question_answer_pairs

# 3. Process each URL
output_dir = Path("data")
output_dir.mkdir(parents=True, exist_ok=True)

for idx, url in enumerate(urls, 1):
    logger.info(f"Processing URL {idx}/{len(urls)}: {url}")
    
    try:
        response = session.get(url, allow_redirects=False)
        
        if response.status_code in {301, 302}:
            logger.info("   Redirect detected, checking URL.")
            final_url = response.headers.get('Location')
            if final_url:
                response = session.get(final_url)
        elif response.status_code != 200:
            logger.warning("   Invalid URL or access problem.")
            continue

        soup = BeautifulSoup(response.content, 'html.parser')
        qa_pairs = extract_question_answer(soup)
        logger.info(f"   {len(qa_pairs)} question-answer pairs found.")
        
        if qa_pairs:
            # Create a file name using the URL and replace forbidden characters
            file_name = url.replace(":", "_").replace("/", "_") + ".txt"
            output_file = output_dir / file_name
            
            try:
                with open(output_file, "w", encoding="utf-8") as file:
                    file.write(f"Source URL: {url}\n\n")
                    for qa in qa_pairs:
                        file.write(f"Question: {qa['question']}\nAnswer: {qa['answer']}\n\n")
                
                logger.info(f"   Results saved to '{output_file}'.")
            except IOError as e:
                logger.error(f"   Error writing to file: {e}")
        else:
            logger.info("   No question-answer pairs found, file will not be created.")
    
    except requests.exceptions.RequestException as e:
        logger.error(f"   Error occurred: {e}")
    
    time.sleep(1)  # Sleep to avoid overwhelming the server

logger.info("Processing completed! Results for pages with question-answer pairs saved in 'data' directory.")
# Out:
# 2024-10-18 17:35:20,711 - INFO - Requesting sitemap URL: https://www.telekom.de/ueber-das-unternehmen/robots/sitemap
# 2024-10-18 17:35:21,070 - INFO - Processing sitemap XML...
# 2024-10-18 17:35:21,076 - INFO - 4866 URLs found.
# 2024-10-18 17:35:21,077 - INFO - Processing URL 1/4866: https://www.telekom.de/apps
# 2024-10-18 17:35:21,141 - INFO -    Redirect detected, checking URL.
# 2024-10-18 17:35:21,635 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:21,635 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:22,641 - INFO - Processing URL 2/4866: https://www.telekom.de/apps/meinmagenta-app
# 2024-10-18 17:35:23,057 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:23,057 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:24,062 - INFO - Processing URL 3/4866: https://www.telekom.de/apps/voicemail
# 2024-10-18 17:35:24,479 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:24,480 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:25,481 - INFO - Processing URL 4/4866: https://www.telekom.de/bestellung/bestellung-08003308000
# 2024-10-18 17:35:25,704 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:25,704 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:26,706 - INFO - Processing URL 5/4866: https://www.telekom.de/datenschutzhinweise
# 2024-10-18 17:35:27,093 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:27,094 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:28,100 - INFO - Processing URL 6/4866: https://www.telekom.de/e-mail
# 2024-10-18 17:35:28,592 - INFO -    7 question-answer pairs found.
# 2024-10-18 17:35:28,593 - INFO -    Results saved to 'data/https___www.telekom.de_e-mail.txt'.
# 2024-10-18 17:35:29,598 - INFO - Processing URL 7/4866: https://www.telekom.de/e-mail/e-mail-center
# 2024-10-18 17:35:29,868 - INFO -    3 question-answer pairs found.
# 2024-10-18 17:35:29,869 - INFO -    Results saved to 'data/https___www.telekom.de_e-mail_e-mail-center.txt'.
# 2024-10-18 17:35:30,871 - INFO - Processing URL 8/4866: https://www.telekom.de/e-mail/e-mail-made-in-germany
# 2024-10-18 17:35:31,259 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:31,259 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:32,260 - INFO - Processing URL 9/4866: https://www.telekom.de/e-mail/e-mail-siegel
# 2024-10-18 17:35:32,552 - INFO -    3 question-answer pairs found.
# 2024-10-18 17:35:32,553 - INFO -    Results saved to 'data/https___www.telekom.de_e-mail_e-mail-siegel.txt'.
# 2024-10-18 17:35:33,558 - INFO - Processing URL 10/4866: https://www.telekom.de/e-mail/mail-m
# 2024-10-18 17:35:33,846 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:33,846 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:34,852 - INFO - Processing URL 11/4866: https://www.telekom.de/erleben
# 2024-10-18 17:35:34,898 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:34,898 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:35,904 - INFO - Processing URL 12/4866: https://www.telekom.de/erleben/shop
# 2024-10-18 17:35:35,982 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:35,983 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:36,988 - INFO - Processing URL 13/4866: https://www.telekom.de/festnetz
# 2024-10-18 17:35:37,252 - INFO -    4 question-answer pairs found.
# 2024-10-18 17:35:37,253 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz.txt'.
# 2024-10-18 17:35:38,260 - INFO - Processing URL 14/4866: https://www.telekom.de/festnetz/heimvernetzung
# 2024-10-18 17:35:38,636 - INFO -    8 question-answer pairs found.
# 2024-10-18 17:35:38,637 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_heimvernetzung.txt'.
# 2024-10-18 17:35:39,639 - INFO - Processing URL 15/4866: https://www.telekom.de/festnetz/heimvernetzung/mesh-funktionen
# 2024-10-18 17:35:39,736 - INFO -    Redirect detected, checking URL.
# 2024-10-18 17:35:39,736 - ERROR -    Error occurred: Invalid URL '/festnetz/heimvernetzung/mesh-technologie': No scheme supplied. Perhaps you meant https:///festnetz/heimvernetzung/mesh-technologie?
# 2024-10-18 17:35:40,737 - INFO - Processing URL 16/4866: https://www.telekom.de/festnetz/heimvernetzung/mesh-technologie
# 2024-10-18 17:35:41,219 - INFO -    11 question-answer pairs found.
# 2024-10-18 17:35:41,220 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_heimvernetzung_mesh-technologie.txt'.
# 2024-10-18 17:35:42,225 - INFO - Processing URL 17/4866: https://www.telekom.de/festnetz/heimvernetzung/wlan-optimierung
# 2024-10-18 17:35:42,502 - INFO -    5 question-answer pairs found.
# 2024-10-18 17:35:42,503 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_heimvernetzung_wlan-optimierung.txt'.
# 2024-10-18 17:35:43,508 - INFO - Processing URL 18/4866: https://www.telekom.de/festnetz/heimvernetzung/wlan-pakete
# 2024-10-18 17:35:43,819 - INFO -    8 question-answer pairs found.
# 2024-10-18 17:35:43,820 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_heimvernetzung_wlan-pakete.txt'.
# 2024-10-18 17:35:44,825 - INFO - Processing URL 19/4866: https://www.telekom.de/festnetz/magenta-zuhause-app
# 2024-10-18 17:35:45,094 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:35:45,095 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_magenta-zuhause-app.txt'.
# 2024-10-18 17:35:46,098 - INFO - Processing URL 20/4866: https://www.telekom.de/festnetz/mesh-wlan
# 2024-10-18 17:35:46,507 - INFO -    7 question-answer pairs found.
# 2024-10-18 17:35:46,508 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_mesh-wlan.txt'.
# 2024-10-18 17:35:47,514 - INFO - Processing URL 21/4866: https://www.telekom.de/festnetz/tarife-und-optionen/dsl-anschluss
# 2024-10-18 17:35:47,752 - INFO -    3 question-answer pairs found.
# 2024-10-18 17:35:47,753 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_tarife-und-optionen_dsl-anschluss.txt'.
# 2024-10-18 17:35:48,754 - INFO - Processing URL 22/4866: https://www.telekom.de/festnetz/tarife-und-optionen/dsl-ohne-vertragslaufzeit
# 2024-10-18 17:35:49,169 - INFO -    8 question-answer pairs found.
# 2024-10-18 17:35:49,170 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_tarife-und-optionen_dsl-ohne-vertragslaufzeit.txt'.
# 2024-10-18 17:35:50,172 - INFO - Processing URL 23/4866: https://www.telekom.de/festnetz/tarife-und-optionen/dsl-tarife
# 2024-10-18 17:35:50,478 - INFO -    2 question-answer pairs found.
# 2024-10-18 17:35:50,479 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_tarife-und-optionen_dsl-tarife.txt'.
# 2024-10-18 17:35:51,481 - INFO - Processing URL 24/4866: https://www.telekom.de/festnetz/tarife-und-optionen/fuer-junge-leute
# 2024-10-18 17:35:51,827 - INFO -    6 question-answer pairs found.
# 2024-10-18 17:35:51,828 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz_tarife-und-optionen_fuer-junge-leute.txt'.
# 2024-10-18 17:35:52,834 - INFO - Processing URL 25/4866: https://www.telekom.de/festnetz/tarife-und-optionen/internet-dsl/tarifauswahl
# 2024-10-18 17:35:52,880 - INFO -    Redirect detected, checking URL.
# 2024-10-18 17:35:52,881 - ERROR -    Error occurred: Invalid URL '/shop/tarife/internet-tarife': No scheme supplied. Perhaps you meant https:///shop/tarife/internet-tarife?
# 2024-10-18 17:35:53,884 - INFO - Processing URL 26/4866: https://www.telekom.de/festnetz/tarife-und-optionen/internetanbieter
# 2024-10-18 17:35:54,166 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:35:54,166 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:35:55,172 - INFO - Processing URL 27/4866: https://www.telekom.de/festnetz/tarife-und-optionen/internetanschluss
# 2024-10-18 17:35:55,434 - INFO -    4 question-answer pairs found.
# 2024-10-18 17:35:55,435 - INFO -    Results saved to 'data/https___www.telekom.de_festnetz
- INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-ausland.txt'.
# 2024-10-18 17:36:40,134 - INFO - Processing URL 60/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-inklusivvolumen
# 2024-10-18 17:36:41,150 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:41,151 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-inklusivvolumen.txt'.
# 2024-10-18 17:36:42,156 - INFO - Processing URL 61/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-kuendigen
# 2024-10-18 17:36:42,964 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:42,965 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-kuendigen.txt'.
# 2024-10-18 17:36:43,971 - INFO - Processing URL 62/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-offline
# 2024-10-18 17:36:44,871 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:44,872 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-offline.txt'.
# 2024-10-18 17:36:45,878 - INFO - Processing URL 63/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-parallel
# 2024-10-18 17:36:46,713 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:46,714 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-parallel.txt'.
# 2024-10-18 17:36:47,716 - INFO - Processing URL 64/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-support
# 2024-10-18 17:36:48,666 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:48,667 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-support.txt'.
# 2024-10-18 17:36:49,672 - INFO - Processing URL 65/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-testen
# 2024-10-18 17:36:50,529 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:50,530 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-testen.txt'.
# 2024-10-18 17:36:51,532 - INFO - Processing URL 66/4866: https://www.telekom.de/hilfe/apps-dienste/apps/apple-music/apple-music-volle-nutzung
# 2024-10-18 17:36:52,543 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:36:52,544 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_apple-music_apple-music-volle-nutzung.txt'.
# 2024-10-18 17:36:53,549 - INFO - Processing URL 67/4866: https://www.telekom.de/hilfe/apps-dienste/apps/datengeschenk
# 2024-10-18 17:36:54,489 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:36:54,490 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:36:55,492 - INFO - Processing URL 68/4866: https://www.telekom.de/hilfe/apps-dienste/apps/downloads-smart-speaker
# 2024-10-18 17:36:56,346 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:36:56,346 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:36:57,352 - INFO - Processing URL 69/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app
# 2024-10-18 17:36:58,301 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:36:58,302 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:36:59,307 - INFO - Processing URL 70/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/anmeldung
# 2024-10-18 17:37:00,237 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:00,238 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_anmeldung.txt'.
# 2024-10-18 17:37:01,244 - INFO - Processing URL 71/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen
# 2024-10-18 17:37:02,099 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:02,099 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:03,100 - INFO - Processing URL 72/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/anmeldedaten
# 2024-10-18 17:37:04,381 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:04,382 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_anmeldedaten.txt'.
# 2024-10-18 17:37:05,388 - INFO - Processing URL 73/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/app-wechseln
# 2024-10-18 17:37:06,407 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:06,408 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_app-wechseln.txt'.
# 2024-10-18 17:37:07,414 - INFO - Processing URL 74/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/eigene-routinen
# 2024-10-18 17:37:08,343 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:08,344 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:09,349 - INFO - Processing URL 75/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/kosten
# 2024-10-18 17:37:10,369 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:10,370 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_kosten.txt'.
# 2024-10-18 17:37:11,372 - INFO - Processing URL 76/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/magentazuhause-app-smarthome
# 2024-10-18 17:37:12,379 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:12,380 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_magentazuhause-app-smarthome.txt'.
# 2024-10-18 17:37:13,382 - INFO - Processing URL 77/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/rechte
# 2024-10-18 17:37:14,354 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:14,355 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_rechte.txt'.
# 2024-10-18 17:37:15,360 - INFO - Processing URL 78/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/telekom-login
# 2024-10-18 17:37:16,334 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:16,334 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_app-funktionen_telekom-login.txt'.
# 2024-10-18 17:37:17,337 - INFO - Processing URL 79/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/voraussetzungen
# 2024-10-18 17:37:18,454 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:18,454 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:19,457 - INFO - Processing URL 80/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/app-funktionen/vorgefertigte-routinen
# 2024-10-18 17:37:20,684 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:20,685 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:21,686 - INFO - Processing URL 81/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-uebertragen
# 2024-10-18 17:37:22,744 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:22,745 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-uebertragen.txt'.
# 2024-10-18 17:37:23,751 - INFO - Processing URL 82/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards
# 2024-10-18 17:37:24,594 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:24,595 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:25,596 - INFO - Processing URL 83/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/funkstandards
# 2024-10-18 17:37:26,568 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:26,569 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_funkstandards.txt'.
# 2024-10-18 17:37:27,571 - INFO - Processing URL 84/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/geraet-nicht-angezeigt
# 2024-10-18 17:37:28,588 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:28,589 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_geraet-nicht-angezeigt.txt'.
# 2024-10-18 17:37:29,595 - INFO - Processing URL 85/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/geraetehersteller
# 2024-10-18 17:37:30,674 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:30,674 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_geraetehersteller.txt'.
# 2024-10-18 17:37:31,676 - INFO - Processing URL 86/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/homematic-hmip-fehlercodes
# 2024-10-18 17:37:32,584 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:32,585 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:33,590 - INFO - Processing URL 87/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/led-symbole-fehlercodes-eurotronic-comet-wifi-heizkoerperthermostats
# 2024-10-18 17:37:34,538 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:34,539 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_led-symbole-fehlercodes-eurotronic-comet-wifi-heizkoerperthermostats.txt'.
# 2024-10-18 17:37:35,545 - INFO - Processing URL 88/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/neuen-raum-anlegen
# 2024-10-18 17:37:36,447 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:36,448 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_neuen-raum-anlegen.txt'.
# 2024-10-18 17:37:37,452 - INFO - Processing URL 89/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/neues-geraet-raum-zuordnen
# 2024-10-18 17:37:38,422 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:38,423 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_neues-geraet-raum-zuordnen.txt'.
# 2024-10-18 17:37:39,428 - INFO - Processing URL 90/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/router-tausch-wechsel-magentazuhause-app
# 2024-10-18 17:37:40,305 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:40,306 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:41,307 - INFO - Processing URL 91/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/smarthome-geraete-importieren
# 2024-10-18 17:37:42,206 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:42,207 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:43,216 - INFO - Processing URL 92/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/wandtaster-verbinden
# 2024-10-18 17:37:44,362 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:44,363 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_wandtaster-verbinden.txt'.
# 2024-10-18 17:37:45,368 - INFO - Processing URL 93/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/wechsel-smarthome-zentrale
# 2024-10-18 17:37:46,423 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:46,424 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:47,429 - INFO - Processing URL 94/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/weitere-geraete-importieren
# 2024-10-18 17:37:48,367 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:48,367 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:49,372 - INFO - Processing URL 95/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/geraete-zentralen-funkstandards/zusaetzlich-zentrale
# 2024-10-18 17:37:50,624 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:50,625 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_geraete-zentralen-funkstandards_zusaetzlich-zentrale.txt'.
# 2024-10-18 17:37:51,627 - INFO - Processing URL 96/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/internet-tv-funktionen
# 2024-10-18 17:37:52,356 - INFO -    0 question-answer pairs found.
# 2024-10-18 17:37:52,357 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 17:37:53,362 - INFO - Processing URL 97/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/internet-tv-funktionen/aktivierung-easysupport
# 2024-10-18 17:37:54,397 - INFO -    1 question-answer pairs found.
# 2024-10-18 17:37:54,398 - INFO -    Results saved to 'data/https___www.telekom.de_hilfe_apps-dienste_apps_magenta-zuhause-app_internet-tv-funktionen_aktivierung-easysupport.txt'.
# 2024-10-18 17:37:55,404 - INFO - Processing URL 98/4866: https://www.telekom.de/hilfe/apps-dienste/apps/magenta-zuhause-app/internet-tv-funktion
- INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:35,248 - INFO - Processing URL 4820/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-premium-upgrade-by-telekom-smart-stream-2-0
# 2024-10-18 19:56:35,645 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:35,645 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:36,650 - INFO - Processing URL 4821/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-premium-upgrade-by-telekom-zum-mega-stream-2-0
# 2024-10-18 19:56:36,936 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:36,937 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:37,947 - INFO - Processing URL 4822/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-premium-upgrade-by-telekom-zum-smart-stream-2-0
# 2024-10-18 19:56:38,205 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:38,205 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:39,208 - INFO - Processing URL 4823/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard
# 2024-10-18 19:56:39,503 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:39,503 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:40,511 - INFO - Processing URL 4824/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-12-monats-abo
# 2024-10-18 19:56:40,763 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:40,764 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:41,765 - INFO - Processing URL 4825/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-mit-werbung-by-telekom
# 2024-10-18 19:56:42,044 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:42,045 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:43,055 - INFO - Processing URL 4826/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-monats-abo
# 2024-10-18 19:56:43,321 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:43,322 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:44,332 - INFO - Processing URL 4827/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom
# 2024-10-18 19:56:45,174 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:45,174 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:46,185 - INFO - Processing URL 4828/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom-12m-option
# 2024-10-18 19:56:47,443 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:47,444 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:48,454 - INFO - Processing URL 4829/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom-12m-smart-stream-2-0
# 2024-10-18 19:56:49,134 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:49,134 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:50,140 - INFO - Processing URL 4830/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom-option
# 2024-10-18 19:56:50,417 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:50,417 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:51,424 - INFO - Processing URL 4831/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom-smart-stream-2-0
# 2024-10-18 19:56:52,030 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:52,031 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:53,031 - INFO - Processing URL 4832/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/netflix-standard-upgrade-by-telekom-zum-smart-stream-2-0
# 2024-10-18 19:56:53,321 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:53,322 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:54,337 - INFO - Processing URL 4833/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/paramount-plus
# 2024-10-18 19:56:54,522 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:54,522 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:55,533 - INFO - Processing URL 4834/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/paramount-plus-standard-by-telekom
# 2024-10-18 19:56:56,557 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:56,558 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:57,568 - INFO - Processing URL 4835/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/paramount-plus-standard-by-telekom-12m
# 2024-10-18 19:56:57,965 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:57,966 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:56:58,967 - INFO - Processing URL 4836/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/persoenliche-installation
# 2024-10-18 19:56:59,202 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:56:59,202 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:00,211 - INFO - Processing URL 4837/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/rtl-plus-family-by-telekom
# 2024-10-18 19:57:00,969 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:00,969 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:01,970 - INFO - Processing URL 4838/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/rtl-plus-family-ohne-musik-by-telekom
# 2024-10-18 19:57:02,472 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:02,472 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:03,482 - INFO - Processing URL 4839/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/rtl-plus-max-by-telekom
# 2024-10-18 19:57:03,771 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:03,771 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:04,775 - INFO - Processing URL 4840/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/rtl-plus-max-ohne-musik-by-telekom
# 2024-10-18 19:57:05,117 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:05,118 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:06,128 - INFO - Processing URL 4841/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/rtl-plus-optionen
# 2024-10-18 19:57:06,526 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:06,526 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:07,537 - INFO - Processing URL 4842/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/sicherheitspaket-komplett-m
# 2024-10-18 19:57:07,803 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:07,803 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:08,813 - INFO - Processing URL 4843/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/sicherheitspaket-komplett-s
# 2024-10-18 19:57:09,236 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:09,237 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:10,239 - INFO - Processing URL 4844/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/spotify-premium
# 2024-10-18 19:57:10,426 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:10,427 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:11,437 - INFO - Processing URL 4845/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/spotify-premium-3-monate-kostenlos
# 2024-10-18 19:57:12,209 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:12,209 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:13,220 - INFO - Processing URL 4846/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/spotify-premium-testen
# 2024-10-18 19:57:13,563 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:13,563 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:14,565 - INFO - Processing URL 4847/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/telefonie-optionen
# 2024-10-18 19:57:14,739 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:14,740 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:15,750 - INFO - Processing URL 4848/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/telekom-sicherheitspaket-l
# 2024-10-18 19:57:16,297 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:16,297 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:17,313 - INFO - Processing URL 4849/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webhosting-basic
# 2024-10-18 19:57:18,567 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:18,568 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:19,570 - INFO - Processing URL 4850/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webhosting-pro
# 2024-10-18 19:57:19,879 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:19,879 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:20,879 - INFO - Processing URL 4851/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webshop-basic
# 2024-10-18 19:57:22,024 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:22,025 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:23,033 - INFO - Processing URL 4852/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webshop-basic-mit-einrichtungsservice
# 2024-10-18 19:57:24,137 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:24,138 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:25,148 - INFO - Processing URL 4853/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webshop-pro
# 2024-10-18 19:57:25,931 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:25,932 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:26,939 - INFO - Processing URL 4854/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/webshop-pro-mit-einrichtungsservice
# 2024-10-18 19:57:28,610 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:28,611 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:29,621 - INFO - Processing URL 4855/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/website-basic
# 2024-10-18 19:57:29,942 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:29,942 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:30,952 - INFO - Processing URL 4856/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/website-mit-design-und-pflege-service
# 2024-10-18 19:57:32,640 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:32,640 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:33,642 - INFO - Processing URL 4857/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/website-pro
# 2024-10-18 19:57:33,874 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:33,875 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:34,885 - INFO - Processing URL 4858/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/website-pro-mit-design-service
# 2024-10-18 19:57:36,495 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:36,496 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:37,506 - INFO - Processing URL 4859/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-filme-serien-standard-by-telekom
# 2024-10-18 19:57:38,420 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:38,421 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:39,431 - INFO - Processing URL 4860/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-filme-serien-standard-by-telekom-12m
# 2024-10-18 19:57:39,683 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:39,684 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:40,694 - INFO - Processing URL 4861/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-live-sport-by-telekom-12m-option
# 2024-10-18 19:57:40,971 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:40,971 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:41,982 - INFO - Processing URL 4862/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-live-sport-by-telekom-option
# 2024-10-18 19:57:42,271 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:42,272 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:43,274 - INFO - Processing URL 4863/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-optionen
# 2024-10-18 19:57:43,428 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:43,428 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:44,433 - INFO - Processing URL 4864/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/wow-premium-by-telekom
# 2024-10-18 19:57:44,680 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:44,681 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:45,683 - INFO - Processing URL 4865/4866: https://www.telekom.de/zuhause/tarife-und-optionen/zubuchoptionen/zusaetzliche-rufnummer-fuer-den-universal-oder-ip-basierten-anschluss
# 2024-10-18 19:57:45,889 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:45,889 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:46,900 - INFO - Processing URL 4866/4866: https://www.telekom.de/zuhause/zugang-zu-telekom-diensten
# 2024-10-18 19:57:47,140 - INFO -    0 question-answer pairs found.
# 2024-10-18 19:57:47,140 - INFO -    No question-answer pairs found, file will not be created.
# 2024-10-18 19:57:48,144 - INFO - Processing completed! Results for pages with question-answer pairs saved in 'data' directory.
